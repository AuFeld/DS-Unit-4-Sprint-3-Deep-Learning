# %% [markdown]
# <a href="https://colab.research.google.com/github/AuFeld/DS-Unit-4-Sprint-3-Deep-Learning/blob/master/module1-rnn-and-lstm/CG_DS_431_RNN_and_LSTM_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
# installs

! pip install --upgrade tensorflow

# %%
# imports

import numpy as np 
import random
import sys
import urllib.request
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM

# %%
# read in data

full_text = []
url = "https://www.gutenberg.org/files/100/100-0.txt"
for line in urllib.request.urlopen(url):
  full_text.append(line.decode('utf-8'))

# %%
# find last line of text

full_text[-435:-429]
# Out:
# ['And yokes her silver doves; by whose swift aid\r\n',
#  'Their mistress mounted through the empty skies,\r\n',
#  'In her light chariot quickly is convey’d;           1192\r\n',
#  '  Holding their course to Paphos, where their queen\r\n',
#  '  Means to immure herself and not be seen.\r\n',
#  '\r\n']

# %%
# find first line of text

full_text[138:140]
# Out:
# ['\r\n', 'From fairest creatures we desire increase,\r\n']

# %%
# strip lines from remaining HTML characters

cleaned_full_text = []
for line in full_text[139:-430]:
  cleaned_full_text.append(line.strip())

# %%
len(cleaned_full_text)
# Out:
# 166333

# %%
full_text[44:129:2]
# Out:
# ['               ALL’S WELL THAT ENDS WELL\r\n',
#  '               THE TRAGEDY OF ANTONY AND CLEOPATRA\r\n',
#  '               AS YOU LIKE IT\r\n',
#  '               THE COMEDY OF ERRORS\r\n',
#  '               THE TRAGEDY OF CORIOLANUS\r\n',
#  '               CYMBELINE\r\n',
#  '               THE TRAGEDY OF HAMLET, PRINCE OF DENMARK\r\n',
#  '               THE FIRST PART OF KING HENRY THE FOURTH\r\n',
#  '               THE SECOND PART OF KING HENRY THE FOURTH\r\n',
#  '               THE LIFE OF KING HENRY THE FIFTH\r\n',
#  '               THE FIRST PART OF HENRY THE SIXTH\r\n',
#  '               THE SECOND PART OF KING HENRY THE SIXTH\r\n',
#  '               THE THIRD PART OF KING HENRY THE SIXTH\r\n',
#  '               KING HENRY THE EIGHTH\r\n',
#  '               KING JOHN\r\n',
#  '               THE TRAGEDY OF JULIUS CAESAR\r\n',
#  '               THE TRAGEDY OF KING LEAR\r\n',
#  '               LOVE’S LABOUR’S LOST\r\n',
#  '               THE TRAGEDY OF MACBETH\r\n',
#  '               MEASURE FOR MEASURE\r\n',
#  '               THE MERCHANT OF VENICE\r\n',
#  '               THE MERRY WIVES OF WINDSOR\r\n',
#  '               A MIDSUMMER NIGHT’S DREAM\r\n',
#  '               MUCH ADO ABOUT NOTHING\r\n',
#  '               THE TRAGEDY OF OTHELLO, MOOR OF VENICE\r\n',
#  '               PERICLES, PRINCE OF TYRE\r\n',
#  '               KING RICHARD THE SECOND\r\n',
#  '               KING RICHARD THE THIRD\r\n',
#  '               THE TRAGEDY OF ROMEO AND JULIET\r\n',
#  '               THE TAMING OF THE SHREW\r\n',
#  '               THE TEMPEST\r\n',
#  '               THE LIFE OF TIMON OF ATHENS\r\n',
#  '               THE TRAGEDY OF TITUS ANDRONICUS\r\n',
#  '               THE HISTORY OF TROILUS AND CRESSIDA\r\n',
#  '               TWELFTH NIGHT; OR, WHAT YOU WILL\r\n',
#  '               THE TWO GENTLEMEN OF VERONA\r\n',
#  '               THE TWO NOBLE KINSMEN\r\n',
#  '               THE WINTER’S TALE\r\n',
#  '               A LOVER’S COMPLAINT\r\n',
#  '               THE PASSIONATE PILGRIM\r\n',
#  '               THE PHOENIX AND THE TURTLE\r\n',
#  '               THE RAPE OF LUCRECE\r\n',
#  '               VENUS AND ADONIS\r\n']

# %%
# create titles data

titles = []
for line in full_text[44:129:2]:
  titles.append(line.strip())

# %%
titles[0]
# Out:
# 'ALL’S WELL THAT ENDS WELL'

# %%
cleaned_full_text[2760:2770]
# Out:
# ['Was sleeping by a virgin hand disarmed.',
#  'This brand she quenched in a cool well by,',
#  'Which from Love’s fire took heat perpetual,',
#  'Growing a bath and healthful remedy,',
#  'For men discased, but I my mistress’ thrall,',
#  'Came there for cure and this by that I prove,',
#  'Love’s fire heats water, water cools not love.',
#  '',
#  '',
#  'THE END']

# %%
# seperate out sonnets

sonnets = []
for line in cleaned_full_text[:2767]:
  sonnets.append(line)

# %%
sonnets[-1]
# Out:
# 'Love’s fire heats water, water cools not love.'

# %%
### use titles list to create first draft of model ###

# gather all text

text = " ".join(titles)

# create unique characters list

chars = list(set(text))

# create character lookup tables

char_int = {c:i for i, c in enumerate(chars)}
int_char = {i:c for i, c in enumerate(chars)}

len(chars)
# Out:
# 28

# %%
# find average length of titles

lengths = []
sum_num = 0

for title in titles: 
  lengths.append(len(title))

for length in lengths:
  sum_num += length

sum_num / len(lengths)
# Out:
# 25.372093023255815

# %%
# create sequence data

maxlen = 25
step = 5

# create encoded data

encoded = [char_int[c] for c in text]

# create empty sequence and next character lists

sequences = []
next_char = []

# fill empty lists

for i in range(0, len(encoded) - maxlen, step):
  sequences.append(encoded[i : i + maxlen])
  next_char.append(encoded[i + maxlen])

print('Sequence Qty: ', len(sequences))
# Out:
# Sequence Qty:  222

# %%
# one hot encode data to prepare for model

x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
  for t, char in enumerate(sequence):
    x[i, t, char] = 1
  y[i, next_char[i]] = 1

# %%
# build LSTM model

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               80384
# _________________________________________________________________
# dense (Dense)                (None, 28)                3612
# =================================================================
# Total params: 83,996
# Trainable params: 83,996
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create functions to make use of model outputs

def indexer(preds):
  # helper function to take highest probability and pull given index
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / 1
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

def on_epoch_end(epoch, _): 
  # function to generate predicted text at each epoch
  print()
  print('---- Generating text after Epoch: %d' % epoch)

  start_index = random.randint(0, len(text) - maxlen - 1)

  generated = ''

  sentence = text[start_index: start_index + maxlen]

  generated += sentence

  print('---- Generating w/ seed: "' + sentence + '"')
  # sys.stdout.write(generated)

  for i in range(25): 
    x_pred = np.zeros((1, maxlen, len(chars)))
    for t, char in enumerate(sentence): 
      x_pred[0, t, char_int[char]] = 1
    
    preds = model.predict(x_pred, verbose=0)[0]
    next_index = indexer(preds)
    next_char = int_char[next_index]

    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
  print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
# fit the model

model.fit(x, y, 
          batch_size=32, 
          epochs=100, 
          callbacks=[print_callback])
# Out:
# Train on 222 samples
# Epoch 1/100
# 160/222 [====================>.........] - ETA: 0s - loss: 3.3181
# ---- Generating text after Epoch: 0
# ---- Generating w/ seed: "A THE TWO NOBLE KINSMEN T"
# H SJWJDOOT I;H’’FI’FMPUGM
# 222/222 [==============================] - 3s 12ms/sample - loss: 3.3118
# Epoch 2/100
# 160/222 [====================>.........] - ETA: 0s - loss: 3.2346
# ---- Generating text after Epoch: 1
# ---- Generating w/ seed: " LABOUR’S LOST THE TRAGED"
# IR UFIOYEKUAJ WTBLXHADNV
# 222/222 [==============================] - 1s 5ms/sample - loss: 3.2067
# Epoch 3/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.9670
# ---- Generating text after Epoch: 2
# ---- Generating w/ seed: "E SECOND PART OF KING HEN"
# E;EDEEIEEEOXRI OA BODHTT
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.9985
# Epoch 4/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8329
# ---- Generating text after Epoch: 3
# ---- Generating w/ seed: "BOUR’S LOST THE TRAGEDY O"
# SNTR OTONATARDEPETTIEFUEE
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.8781
# Epoch 5/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8796
# ---- Generating text after Epoch: 4
# ---- Generating w/ seed: "ERICLES, PRINCE OF TYRE K"
# TREYTIRITE RINNOHP’NRHUTY
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.8450
# Epoch 6/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8411
# ---- Generating text after Epoch: 5
# ---- Generating w/ seed: "OVE’S LABOUR’S LOST THE T"
# ROIEI REAO’YTYYEYDAT G OD
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.8253
# Epoch 7/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.8049
# ---- Generating text after Epoch: 6
# ---- Generating w/ seed: "S YOU LIKE IT THE COMEDY "
# EUF TUOOIEG R URNIHVTPDEO
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.8138
# Epoch 8/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7776
# ---- Generating text after Epoch: 7
# ---- Generating w/ seed: "LINE THE TRAGEDY OF HAMLE"
# T TDHI TTFO D  SMOFTNXEFO
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7924
# Epoch 9/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7842
# ---- Generating text after Epoch: 8
# ---- Generating w/ seed: "RK THE FIRST PART OF KING"
# EAFHTNGKANRODNIEIDINNNHHL
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7791
# Epoch 10/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7085
# ---- Generating text after Epoch: 9
# ---- Generating w/ seed: " OF TYRE KING RICHARD THE"
# VHR TAGGTEGTNWEJ DDAE OUM
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7727
# Epoch 11/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7835
# ---- Generating text after Epoch: 10
# ---- Generating w/ seed: "CRESSIDA TWELFTH NIGHT; O"
#  S PP OUAREHFONIDD RIRYIG
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7765
# Epoch 12/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7301
# ---- Generating text after Epoch: 11
# ---- Generating w/ seed: "RY OF TROILUS AND CRESSID"
# VGOA E  PTTAIG HY TMAEYEF
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7449
# Epoch 13/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.7155
# ---- Generating text after Epoch: 12
# ---- Generating w/ seed: "F ROMEO AND JULIET THE TA"
# IAREE RNETOUNWNTIIIPURFRH
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7293
# Epoch 14/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.6892
# ---- Generating text after Epoch: 13
# ---- Generating w/ seed: " WINDSOR A MIDSUMMER NIGH"
# EAUMEURPE NANELVLGEIEETTA
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.7086
# Epoch 15/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.6763
# ---- Generating text after Epoch: 14
# ---- Generating w/ seed: "HISTORY OF TROILUS AND CR"
# AESRUAEFHE RSRNG UHTFEURH
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.6741
# Epoch 16/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.6666
# ---- Generating text after Epoch: 15
# ---- Generating w/ seed: " NOBLE KINSMEN THE WINTER"
# I TAHWNGTODOA LEDSA DE FI
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.6510
# Epoch 17/100
# 192/222 [========================>.....] - ETA: 0s - loss: 2.6234
# ---- Generating text after Epoch: 16
# ---- Generating w/ seed: "F LUCRECE VENUS AND ADONI"
# TNLL DWYSIOTTLYTT VIYPDA
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.6005
# Epoch 18/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.5802
# ---- Generating text after Epoch: 17
# ---- Generating w/ seed: "CORIOLANUS CYMBELINE THE "
# HHWEPO OWRAAIFYOPNUMNYAMI
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.5785
# Epoch 19/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.5992
# ---- Generating text after Epoch: 18
# ---- Generating w/ seed: "SUMMER NIGHT’S DREAM MUCH"
# EGORME PH EYHTDJL T E U D
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.5578
# Epoch 20/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.5013
# ---- Generating text after Epoch: 19
# ---- Generating w/ seed: "OVE’S LABOUR’S LOST THE T"
# IOXAFERLR E UENKMNTI WGYU
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.5130
# Epoch 21/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.5185
# ---- Generating text after Epoch: 20
# ---- Generating w/ seed: "HE TWO GENTLEMEN OF VERON"
# MHEWINNAMAATTH N PO NVNE
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.4544
# Epoch 22/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.4138
# ---- Generating text after Epoch: 21
# ---- Generating w/ seed: "NS THE TRAGEDY OF TITUS A"
# IG HEMHAADERO D  RONGN YT
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.3762
# Epoch 23/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.3554
# ---- Generating text after Epoch: 22
# ---- Generating w/ seed: "THE TRAGEDY OF OTHELLO, M"
# TNS NUNADV,ETMMH’A SV ITH
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.3310
# Epoch 24/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.2897
# ---- Generating text after Epoch: 23
# ---- Generating w/ seed: "E FOURTH THE LIFE OF KING"
# ANR VNPNYE OEEUHT HEHFORI
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.2705
# Epoch 25/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.2625
# ---- Generating text after Epoch: 24
# ---- Generating w/ seed: "CE PERICLES, PRINCE OF TY"
# NRIAAE EAAE CTUFTGIAHN  O
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.2050
# Epoch 26/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.1612
# ---- Generating text after Epoch: 25
# ---- Generating w/ seed: "ET, PRINCE OF DENMARK THE"
# EFPGH OSO LEGMBIRENGANEHD
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.1915
# Epoch 27/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.1115
# ---- Generating text after Epoch: 26
# ---- Generating w/ seed: " TRAGEDY OF ROMEO AND JUL"
# RTSOHT APHE ,SHN MIHCTIKO
# 222/222 [==============================] - 1s 6ms/sample - loss: 2.1701
# Epoch 28/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.0399
# ---- Generating text after Epoch: 27
# ---- Generating w/ seed: " ATHENS THE TRAGEDY OF TI"
#  RI NPNDERIN IGEEHEREROPD
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.0638
# Epoch 29/100
# 160/222 [====================>.........] - ETA: 0s - loss: 2.1013
# ---- Generating text after Epoch: 28
# ---- Generating w/ seed: "RTH THE SECOND PART OF KI"
# NAORA T LETE ROF T PEL AU
# 222/222 [==============================] - 1s 5ms/sample - loss: 2.0570
# Epoch 30/100
# 192/222 [========================>.....] - ETA: 0s - loss: 1.9974
# ---- Generating text after Epoch: 29
# ---- Generating w/ seed: " OF JULIUS CAESAR THE TRA"
# GGED OUO A DME NMYE  IVON
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.9866
# Epoch 31/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.8989
# ---- Generating text after Epoch: 30
# ---- Generating w/ seed: "F VENICE PERICLES, PRINCE"
# ARERGPETFYFPFKAAHPFPPR’,
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.8970
# Epoch 32/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.8088
# ---- Generating text after Epoch: 31
# ---- Generating w/ seed: "CORIOLANUS CYMBELINE THE "
# THMRANA  OIAN TNTRDH TI
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.8216
# Epoch 33/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.7327
# ---- Generating text after Epoch: 32
# ---- Generating w/ seed: "R’S COMPLAINT THE PASSION"
# SIETTAUTHWGIIINTARGWFXOXD
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.7209
# Epoch 34/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.6000
# ---- Generating text after Epoch: 33
# ---- Generating w/ seed: "UCH ADO ABOUT NOTHING THE"
#  N TTE TTHTHE MOFFOF EE F
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.6634
# Epoch 35/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.7505
# ---- Generating text after Epoch: 34
# ---- Generating w/ seed: "OF HENRY THE SIXTH THE SE"
# GRHTFS  EGFEETRRUNRHOTLHR
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.6542
# Epoch 36/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.5693
# ---- Generating text after Epoch: 35
# ---- Generating w/ seed: " THE TRAGEDY OF CORIOLANU"
# DOYAYOTMIITHHGMYCOT,O HC
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.6104
# Epoch 37/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.5049
# ---- Generating text after Epoch: 36
# ---- Generating w/ seed: "HENRY THE EIGHTH KING JOH"
#  THHEHU HELEODTTAOOOA VNN
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.5291
# Epoch 38/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.4733
# ---- Generating text after Epoch: 37
# ---- Generating w/ seed: " MUCH ADO ABOUT NOTHING T"
# TTH  TTNAG Y UO UTWTHT DG
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.4630
# Epoch 39/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.3516
# ---- Generating text after Epoch: 38
# ---- Generating w/ seed: "HE COMEDY OF ERRORS THE T"
# PPGOOOOA  HTEYTEGYYYTOIIA
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.3952
# Epoch 40/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.2955
# ---- Generating text after Epoch: 39
# ---- Generating w/ seed: " KING HENRY THE FOURTH TH"
# EOOGOOPO   VANNNVVTNMM SM
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.2956
# Epoch 41/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.1828
# ---- Generating text after Epoch: 40
# ---- Generating w/ seed: "HE TRAGEDY OF TITUS ANDRO"
# DIIE TTT ETLTHUN SI E;AUO
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.2310
# Epoch 42/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.1665
# ---- Generating text after Epoch: 41
# ---- Generating w/ seed: "MPEST THE LIFE OF TIMON O"
# NNHRNNRRNVEE,LDAAYWIVOWUJ
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.1987
# Epoch 43/100
# 160/222 [====================>.........] - ETA: 0s - loss: 1.1624
# ---- Generating text after Epoch: 42
# ---- Generating w/ seed: "ATE PILGRIM THE PHOENIX A"
# LXHTVJEF TPGHH   AHEON  O
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.1479
# Epoch 44/100
# 192/222 [========================>.....] - ETA: 0s - loss: 1.0421
# ---- Generating text after Epoch: 43
# ---- Generating w/ seed: "THE SIXTH THE THIRD PART "
#  T EE EGE EFNEEEP,FPEPPHO
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.0459
# Epoch 45/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.9193
# ---- Generating text after Epoch: 44
# ---- Generating w/ seed: " TITUS ANDRONICUS THE HIS"
# YH,I T,IOTTTEREGIRRIRYLDE
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.9890
# Epoch 46/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.9943
# ---- Generating text after Epoch: 45
# ---- Generating w/ seed: "SURE THE MERCHANT OF VENI"
# TTTTHE HEIOIO W F  TE CDE
# 222/222 [==============================] - 1s 5ms/sample - loss: 1.0178
# Epoch 47/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.8945
# ---- Generating text after Epoch: 46
# ---- Generating w/ seed: "ANDRONICUS THE HISTORY OF"
# ITTTTHH SHDRRSEA;P OOFFFF
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.9192
# Epoch 48/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.8634
# ---- Generating text after Epoch: 47
# ---- Generating w/ seed: "RAGEDY OF KING LEAR LOVE’"
# VELHT VGLOESR NTKVMMSMRLN
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.8680
# Epoch 49/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.8304
# ---- Generating text after Epoch: 48
# ---- Generating w/ seed: "Y OF TROILUS AND CRESSIDA"
#  OIDYOITIITIITH  NWT,HVED
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.8360
# Epoch 50/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.7874
# ---- Generating text after Epoch: 49
# ---- Generating w/ seed: " OR, WHAT YOU WILL THE TW"
# DOO OA T TMNMVMMLYOOVSONN
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.7985
# Epoch 51/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.7084
# ---- Generating text after Epoch: 50
# ---- Generating w/ seed: "ICE PERICLES, PRINCE OF T"
# TITHENKRRRREARWEPPEPPT CC
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.7200
# Epoch 52/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.7494
# ---- Generating text after Epoch: 51
# ---- Generating w/ seed: "G RICHARD THE SECOND KING"
# IIIITINDD ANAHADIVUT;XP’D
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.7171
# Epoch 53/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.6350
# ---- Generating text after Epoch: 52
# ---- Generating w/ seed: "ULIET THE TAMING OF THE S"
# EEEEUDPPPFFAESFEFUEIEHEE,
# 222/222 [==============================] - 1s 6ms/sample - loss: 0.6359
# Epoch 54/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.6622
# ---- Generating text after Epoch: 53
# ---- Generating w/ seed: "SURE THE MERCHANT OF VENI"
# NNNTEEEHE ATHCFGEGPVWWDNT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.6186
# Epoch 55/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.6009
# ---- Generating text after Epoch: 54
# ---- Generating w/ seed: "ATHENS THE TRAGEDY OF TIT"
# AHR NNDD RIULTUTTHTTHI  I
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.6084
# Epoch 56/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.5253
# ---- Generating text after Epoch: 55
# ---- Generating w/ seed: "APE OF LUCRECE VENUS AND "
# R NNEEOTOTH HAUIIYIYY  TT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.5672
# Epoch 57/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4833
# ---- Generating text after Epoch: 56
# ---- Generating w/ seed: "US CAESAR THE TRAGEDY OF "
#  NUTHHAYD  STTHHHE AE  E
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.5005
# Epoch 58/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4994
# ---- Generating text after Epoch: 57
# ---- Generating w/ seed: "ELFTH NIGHT; OR, WHAT YOU"
# YYTIIT TTTHHNID D YTITSTE
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4806
# Epoch 59/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4572
# ---- Generating text after Epoch: 58
# ---- Generating w/ seed: "IUS CAESAR THE TRAGEDY OF"
# ORRNNURNDMDCYINXTYAGTAYDI
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4660
# Epoch 60/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4570
# ---- Generating text after Epoch: 59
# ---- Generating w/ seed: "HT’S DREAM MUCH ADO ABOUT"
# UHTTEO  UD  IA MAI  NNYD
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4331
# Epoch 61/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4437
# ---- Generating text after Epoch: 60
# ---- Generating w/ seed: "EDY OF ANTONY AND CLEOPAT"
# AAH DGY IITSYTYTTTTTT IDR
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4194
# Epoch 62/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4359
# ---- Generating text after Epoch: 61
# ---- Generating w/ seed: "RT OF KING HENRY THE FOUR"
# O  MTTHEELE O OONNNANLNNT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4300
# Epoch 63/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4133
# ---- Generating text after Epoch: 62
# ---- Generating w/ seed: " RICHARD THE SECOND KING "
# IIIITI NTHIHNREKUIFIVCKMA
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.4133
# Epoch 64/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.4509
# ---- Generating text after Epoch: 63
# ---- Generating w/ seed: "N OF VERONA THE TWO NOBLE"
# N NTHMMHMTOHDDOM A IITITT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3993
# Epoch 65/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.3788
# ---- Generating text after Epoch: 64
# ---- Generating w/ seed: "CAESAR THE TRAGEDY OF KIN"
# THAA,DDD YLF LTTH TD  ERO
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3564
# Epoch 66/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2996
# ---- Generating text after Epoch: 65
# ---- Generating w/ seed: "CBETH MEASURE FOR MEASURE"
# EEOO  OTAHHHHHRRD OSOOOUP
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.3073
# Epoch 67/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2766
# ---- Generating text after Epoch: 66
# ---- Generating w/ seed: "EMPEST THE LIFE OF TIMON "
#     RNNNNNHNRD  ITHTAHAID
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2589
# Epoch 68/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2654
# ---- Generating text after Epoch: 67
# ---- Generating w/ seed: "RD PART OF KING HENRY THE"
#   THAHH  RRFREAEHEPEEEETU
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2446
# Epoch 69/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2095
# ---- Generating text after Epoch: 68
# ---- Generating w/ seed: "S THE HISTORY OF TROILUS "
#  DY  THH HR   RRIEEAREEEE
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2274
# Epoch 70/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.2101
# ---- Generating text after Epoch: 69
# ---- Generating w/ seed: "LIFE OF KING HENRY THE FI"
# FUO  RTHSEEELE EEEEUUUTTT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.2018
# Epoch 71/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1795
# ---- Generating text after Epoch: 70
# ---- Generating w/ seed: "EW THE TEMPEST THE LIFE O"
# FOFFFOOO NNNNPPPPKV NIYIF
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1818
# Epoch 72/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1459
# ---- Generating text after Epoch: 71
# ---- Generating w/ seed: " THE TRAGEDY OF CORIOLANU"
# N NNYIIYIIIYTHTHTRES  VGI
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1692
# Epoch 73/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1657
# ---- Generating text after Epoch: 72
# ---- Generating w/ seed: "G LEAR LOVE’S LABOUR’S LO"
# N OHH NAAAD N TADA  A TEU
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1613
# Epoch 74/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1702
# ---- Generating text after Epoch: 73
# ---- Generating w/ seed: "OF KING HENRY THE FOURTH "
# TRUELLEEOO   UNNNNNNNNNNN
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1610
# Epoch 75/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1607
# ---- Generating text after Epoch: 74
# ---- Generating w/ seed: "DO ABOUT NOTHING THE TRAG"
# DNDDD      D A  DD NTU  Y
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1485
# Epoch 76/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.1317
# ---- Generating text after Epoch: 75
# ---- Generating w/ seed: " ANDRONICUS THE HISTORY O"
# OPTT  UUU TGDI IS    HTHD
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1406
# Epoch 77/100
# 192/222 [========================>.....] - ETA: 0s - loss: 0.1406
# ---- Generating text after Epoch: 76
# ---- Generating w/ seed: "ST THE LIFE OF TIMON OF A"
# NHNNNNNNIGG IHTMAAMHHVNYX
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1343
# Epoch 78/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1328
# ---- Generating text after Epoch: 77
# ---- Generating w/ seed: "E HISTORY OF TROILUS AND "
#  DAS S    M IWGIIIFR RRRR
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1252
# Epoch 79/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1169
# ---- Generating text after Epoch: 78
# ---- Generating w/ seed: " THE PHOENIX AND THE TURT"
# TEEEE  OA I IEEEELPEPPPPP
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.1181
# Epoch 80/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.1192
# ---- Generating text after Epoch: 79
# ---- Generating w/ seed: "E OF TIMON OF ATHENS THE "
# GGEGGLOOOTUDHHN NNN NNNMM
# 222/222 [==============================] - 1s 6ms/sample - loss: 0.1068
# Epoch 81/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0923
# ---- Generating text after Epoch: 80
# ---- Generating w/ seed: ", MOOR OF VENICE PERICLES"
# P PPPEGGGGROFTTKKPK,GEPOS
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0983
# Epoch 82/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0875
# ---- Generating text after Epoch: 81
# ---- Generating w/ seed: "IFE OF TIMON OF ATHENS TH"
# ,EEGGGGFOOOTTHHMLLLLLNOPU
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0875
# Epoch 83/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0759
# ---- Generating text after Epoch: 82
# ---- Generating w/ seed: "AND CRESSIDA TWELFTH NIGH"
# OS  TOODCOOTNTT   TANYNND
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0805
# Epoch 84/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0767
# ---- Generating text after Epoch: 83
# ---- Generating w/ seed: "CUS THE HISTORY OF TROILU"
# UU TDD OSLHAMMMMMMMCMNIMY
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0740
# Epoch 85/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0644
# ---- Generating text after Epoch: 84
# ---- Generating w/ seed: " OF KING HENRY THE FOURTH"
#  HTEELEEEOO O TNNNNNNNNNN
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0670
# Epoch 86/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0718
# ---- Generating text after Epoch: 85
# ---- Generating w/ seed: " OF VENICE PERICLES, PRIN"
# WEEGTTTTTTFA SKGVAIDRXWMS
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0626
# Epoch 87/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0585
# ---- Generating text after Epoch: 86
# ---- Generating w/ seed: ", WHAT YOU WILL THE TWO G"
# OOTTT NNNNNNVNYYYYYYMTAAH
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0571
# Epoch 88/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0443
# ---- Generating text after Epoch: 87
# ---- Generating w/ seed: "H THE SECOND PART OF KING"
# GGERRRTTTEGGDMVVLXONXVL’N
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0533
# Epoch 89/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0404
# ---- Generating text after Epoch: 88
# ---- Generating w/ seed: "RINCE OF TYRE KING RICHAR"
# RRREEEGGOP PUTTAINRARSXRR
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0502
# Epoch 90/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0499
# ---- Generating text after Epoch: 89
# ---- Generating w/ seed: "HENS THE TRAGEDY OF TITUS"
# NRNHDDYIIOTTTTTHHYTYMYYYG
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0492
# Epoch 91/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0456
# ---- Generating text after Epoch: 90
# ---- Generating w/ seed: " TYRE KING RICHARD THE SE"
#  OTTHIIIIDDT RT TTETTTH G
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0553
# Epoch 92/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0731
# ---- Generating text after Epoch: 91
# ---- Generating w/ seed: "ING HENRY THE SIXTH THE T"
# ORROROR RR    TE TEHNR UR
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0710
# Epoch 93/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0518
# ---- Generating text after Epoch: 92
# ---- Generating w/ seed: "HE FIFTH THE FIRST PART O"
# FFF NRRNNTTEE DOD OATAHHN
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0567
# Epoch 94/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0479
# ---- Generating text after Epoch: 93
# ---- Generating w/ seed: "THE TRAGEDY OF KING LEAR "
# VVVVLVLLVLLRLN OSN ONNONO
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0483
# Epoch 95/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0421
# ---- Generating text after Epoch: 94
# ---- Generating w/ seed: "AS YOU LIKE IT THE COMEDY"
# D    ARRRRIEEEERE EEFFFII
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0456
# Epoch 96/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0371
# ---- Generating text after Epoch: 95
# ---- Generating w/ seed: "TH THE FIRST PART OF HENR"
# RRREEEEPPOOTTTIKTKX NKSVR
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0387
# Epoch 97/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0381
# ---- Generating text after Epoch: 96
# ---- Generating w/ seed: "LOVER’S COMPLAINT THE PAS"
# IIIIEEEETTEGGGEGGTTGV GBB
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0363
# Epoch 98/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0318
# ---- Generating text after Epoch: 97
# ---- Generating w/ seed: "L THAT ENDS WELL THE TRAG"
# DDOD   O  NNPNNYDY YIHTOT
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0316
# Epoch 99/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0287
# ---- Generating text after Epoch: 98
# ---- Generating w/ seed: "E WINTER’S TALE A LOVER’S"
# SOSLPPENPTTTTTHHEHLGXKOOX
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0288
# Epoch 100/100
# 160/222 [====================>.........] - ETA: 0s - loss: 0.0265
# ---- Generating text after Epoch: 99
# ---- Generating w/ seed: "F WINDSOR A MIDSUMMER NIG"
# OOSSO  TATYEIINGG STT THK
# 222/222 [==============================] - 1s 5ms/sample - loss: 0.0268

# %%
### try with sonnets ### 

# gather all text

text = " ".join(sonnets)

# create unique character list

chars = list(set(text))

# create character lookup tables

char_int = {c:i for i, c in enumerate(chars)}
int_char = {i:c for i, c in enumerate(chars)}

len(chars)
# Out:
# 71

# %%
# create sequence data

maxlen = 40
step = 5

# create encoded data

encoded = [char_int[c] for c in text]

# create empty sequence and next character lists

sequences = []
next_char = []

# fill empty lists

for i in range(0, len(encoded) - maxlen, step):
  sequences.append(encoded[i : i + maxlen])
  next_char.append(encoded[i + maxlen])

print('Sequence Qty: ', len(sequences))
# Out:
# Sequence Qty:  18918

# %%
# one hot encode data to prepare for model

x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences): 
  for t, char in enumerate(sequence): 
    x[i, t, char] = 1
  y[i, next_char[i]] = 1

# %%
# build LSTM model

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               102400
# _________________________________________________________________
# dense_1 (Dense)              (None, 71)                9159
# =================================================================
# Total params: 111,559
# Trainable params: 111,559
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create functions to make use of model outputs

def indexer(preds):
  # helper function to take highest probability & pull given index
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / 1
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

def on_epoch_end(epoch, _):
  # function to generate predicted text at each epoch
  print()
  print('---- Generating text after Epoch: %d' % epoch)

  start_index = random.randint(0, len(text) - maxlen - 1)

  generated = ''

  sentence = text[start_index: start_index + maxlen]

  generated += sentence

  print('---- Generating with seed: "' + sentence + '"')
  sys.stdout.write("\n")
  
  print('                 %d' % epoch)
  sys.stdout.write(generated)
  sys.stdout.write("\n")

  for i in range(13):
    for i in range(maxlen):   
      x_pred = np.zeros((1, maxlen, len(chars)))
      for t, char in enumerate(sentence):
        x_pred[0, t, char_int[char]] = 1

      preds = model.predict(x_pred, verbose=0)[0]
      next_index = indexer(preds)
      next_char = int_char[next_index]

      sentence = sentence[1:] + next_char

      sys.stdout.write(next_char)
      sys.stdout.flush()
    sys.stdout.write("\n")
  print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
# fit model

model.fit(x, y,
          batch_size=32, 
          epochs=100, 
          callbacks=[print_callback])
# Out:
# Train on 18918 samples
# Epoch 1/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.9542
# ---- Generating text after Epoch: 0
# ---- Generating with seed: " afloat, Whilst he upon your soundless d"
#
#                  0
#  afloat, Whilst he upon your soundless d
# ntleasel0e hots’nhLsd as ays vo he, she
# stnes iLhitu ogaape ii gr uerm dole gugs
#  the ue l vLtadtabf fonn hlnrs uugt eve
# yoaatd dhhmrd foea tou-i ooier fso, ’o T
# haN ArN aos, mats toreal oin ha-y tda te
# fttsimof, .osnd nrgO Syathahy y wdtbm,li
# ,  anl,o, ude ton try ranedThs har  hato
# l ,vus vany kct in ha on  imt kha  nfc?s
#  ,t ’ad Aeg af ldooHdh nep cocu ve whe
# ie se, ur Oaus pr beg lend lruwr bore ch
# lsc’o tsag msdtdotn cnudB’vim   orisesam
# csyo gorldt maled mdast t ah aebthTors T
# hmje foer gso .mr femfse,oge 5au t rhsos
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 2.9542
# Epoch 2/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.5237
# ---- Generating text after Epoch: 1
# ---- Generating with seed: " do please these curious days, The pain "
#
#                  1
#  do please these curious days, The pain
# houd teve gond bhy pairaee, Thove. buyl:
#  mest Sous Ano’ she n laf ywa: bue wuoth
# y thew Ffyo, taan , by winnd Woos, I ad
# Iote 1ist teat yd raniruso ongryekhat s
# who;r mhl Te wiet oror, Less  arl woy ma
# lurs finrss toatu in, alme. ,ere des egi
# se,, ifn tale thate seyE woepaal, isn th
# o u ly c atec sy twat  or eos: lil whyt,
#  the rpar eot himy st wonst kini mel thi
# w tharc wiwk whel fout otuan thatn nabe,
#  ssave toue? fs tou, tht, ar drit, uaarp
# , bI rsme in toty ror tiiredcEwmanros ei
# ly Bo hn, I wet ort are-l’ins iids, lh O
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 2.5238
# Epoch 3/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.3432
# ---- Generating text after Epoch: 2
# ---- Generating with seed: "ost pay.   80  O how I faint when I of y"
#
#                  2
# ost pay.   80  O how I faint when I of y
# ey, sos kipe Mods ot cuamh thi ny Mith t
# omlde irlobeunn. pinld, dy puve to tun I
#  old sons, Thy3, And batson pqve keos im
# e tounth bndorgeeno deare thing Oorm dho
# t,, an thou thu mith shy meocy tir ait o
# me. th Gy my mnmemTel llobed booln move
# so tholn yt ar., yo  realst elosd Fwov,
# Anuthe mldouy fonkarith male  ound 1ided
#  mocal sto5 boteDhe wo, Ares ot int oe t
# oo sasth veveguree gilt to hoy’d al’fnd
# nop Conver my yave dan, Thou iicd 0rtt t
# hop  ueot shet awnlve nouthaveee bes win
# dve doufoo  palonn thee: ath  houh lo lo
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 2.3430
# Epoch 4/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.2428
# ---- Generating text after Epoch: 3
# ---- Generating with seed: "ght of woe might have remembered My deep"
#
#                  3
# ght of woe might have remembered My deep
# nof mllvems me loom wene, in moveffserpr
# btute I yoveais oul ur woit hem’ taplrin
# , ool ham Tt tiie mar net: Muerocesile t
# hee whe0 ther For, me tor ind and yof ir
# a nouroito erbenot antert thit aon ol ro
# t, Bfther agh weachest beo thor urd bath
# o as I . pitu doew moplilnoner cfaringle
# me, dhou sot fipy Fdsisg, Thil I Buthot
# turasthemist: thiee sdyathind; po5 thoug
# s aces ayd aeond the treimed veamiYow fo
# ue ofoveug, aocerish on thime bting mik
# weat ounhe) thot, hoe . ank thes nim ome
# s ouls, nhrcingpo3d pwallt rtr: or inoon
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 2.2428
# Epoch 5/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.1680
# ---- Generating text after Epoch: 4
# ---- Generating with seed: "ssemble: O ’tis the first, ’tis flattery"
#
#                  4
# ssemble: O ’tis the first, ’tis flattery
# ast Or f, anct ca I vee dipt thou tunel
# thau. Oh mo mimu weeg fread thou nlled,
# Ang co pmewheld th lo, anen pith, Or bua
# d, oin beprts se bpach rad if  man, wh l
# edind mama, And po pily mu that toughit
# than surad nor ko thas thur wht me whin
# of mean kendis enothst sves my yobe rn t
# he herd domlrino homet usinde sire ping
# my lumeing oin os aktn theve lors of my
# wr ow thoy  want Thon wary tho paatke do
# th twait, And deat th mesthe, And pas in
#  lond, Anr forer thec ty whane dace whim
#  the. Thef angher bp siny, Theme, selek,
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 2.1682
# Epoch 6/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.1150
# ---- Generating text after Epoch: 5
# ---- Generating with seed: " the star to every wand’ring bark, Whose"
#
#                  5
#  the star to every wand’ring bark, Whose
#  nat ro nhe, of breaved, anong i8 dunse,
#  So davedes for ingondingsin f abteyes h
# oud dons seasve, poind unt th betaris do
# ond thy Nark, Seer too timer ucith youtd
# eng, Andresear thanhs meense, And cill a
# rouep eik to srof staune and: and bus an
# dot I noatd, asd pinguroun on cinen pore
#  thaw wimu ir fofdl ow in ree-, ound tho
# un.  hy I alet, on ond fareyed sese, Wha
# t trawe, The chthiser argerse dothenthur
# , nnounse finst in ty thiy, wours wreef
# groel litfe sebtangseear My tanldspay fa
# inrowe rar, To wralf, dol thes ar an tho
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 2.1148
# Epoch 7/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.0649
# ---- Generating text after Epoch: 6
# ---- Generating with seed: " thee. Or if they sleep, thy picture in "
#
#                  6
#  thee. Or if they sleep, thy picture in
# tyy, And mathy de)y tam that Noccost the
#  rusccay that at art now im blast that u
# s or soof ir of at toul shous yo, Bun ph
# ind Hon wist fof lis, Thawstily And frot
# hund 6 or the , vow’st ol thet omkd tear
# s bf cars my Or lovsnswich carm bo lo mo
#  his goch aut tate wiptes, Thal theutr n
# o lith ramarod sreptase oplamy ot yore t
# sesely have shiy laweapake, To my acvesi
# nd hal tow frow bth wro the soryecse, no
# w peass bes it diase syfad-ichingh veir.
#  A d erepratstad, Whe love? When ant ead
#  sespaighth demvedry’ shrelf st en sor’s
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 2.0650
# Epoch 8/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 2.0274
# ---- Generating text after Epoch: 7
# ---- Generating with seed: "ing mayst thou taste. The wrinkles which"
#
#                  7
# ing mayst thou taste. The wrinkles which
#  foll wher tabtqul thamet rinesd mer) ay
#  ow, by ur carm, Huprutn’st on thare wy
# mise Sich that fo fomy yy wort, Ord tum
# notit larve fou lot’se. Thy ass le ty, A
# nde,, love, if not or moathang add waver
# , I veat uloudr: in the heel my tay on y
# ougeis’s acxthe sey I leace wive vore my
#  seawn ditt eay thath that last thou sin
#  me surcy werd durt’s thy Whemy ast detu
# rd: fov nethr hee wtht deak whecort the
# piese waruth wingt maddes on the s mh th
#  se rawest cratsts hese thy uwoth ngty a
# nding bithilh miget9 bucinn maghy I im t
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 2.0278
# Epoch 9/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.9923
# ---- Generating text after Epoch: 8
# ---- Generating with seed: "m thee, For nimble thought can jump both"
#
#                  8
# m thee, For nimble thought can jump both
#  lose grepeas elm ne me it ig thy laises
#  co fonth pire corulduch rotr love, Whel
# l st for shy sand eeif cecwhoust ant, an
# d buce in whe wing ars love oo faye kwis
# ene hot whanish fadowen sisthe love. Uhe
# nous bedomy Mughe sillipt of, eny Beses
# sey? What By gistis thuncunf to Aidiid a
# ugelot, Dive bat bet’s ont, a1s now phac
# h I yoot ligh cast ts base thy dotles Ua
# d’s ty andis afdedo dyes forch youndedss
#  som sare I my fove? So bllesw, Be padth
# e wich ututh lick yey by ar and wert yet
#  eo ber, efk promy awieh eave pathy I pl
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 1.9924
# Epoch 10/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.9613
# ---- Generating text after Epoch: 9
# ---- Generating with seed: "ed new: Speak of the spring, and foison "
#
#                  9
# ed new: Speak of the spring, and foison
# m arede sim fowkst, tgitht noure, Beve’i
# te live stoun, and bel the amr.   65  Wh
# or thou formugat in bere worl? Seairy er
# ing or weed ne mo aclondel.  O wory the
# hive Bud, Thell) benue, but in liing: Bu
# t diop, nrepuves, Theering ow pithe prod
# ey-gsoveide. O cham eroppeace, doos wimb
# enos lokd, Thy biaf tin ther ’gringe is
# loaden youre, comered seor to me bean. N
# reser-wand thou ectort dinhall on bin, B
# ut you hed, And deanderk sireerdigh ow o
# f anging by taone. Whess pasteas as the,
#  And Bot to esurs not oy gronl wollogeit
#
# 18918/18918 [==============================] - 61s 3ms/sample - loss: 1.9613
# Epoch 11/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.9314
# ---- Generating text after Epoch: 10
# ---- Generating with seed: "ase of my true love control, Supposed as"
#
#                  10
# ase of my true love control, Supposed as
# t et med-ome, Whentay deye, Art forper a
# n thy sumf, Whongtly, And to berf deyst
# aitnont il wouligh whim thou  if peve’st
#  adl denfdest ig yours apd buk And in hy
#  thoutd’st dutserud wartoford now of tho
# e whrt ay by wantey Leds my amy os astei
# nghafu actort ot ic sthoug the ghatstrev
# en wese thal Mame hat dearty sey lyec li
# tad creac ende, Thas wire cortth nges iw
#  thur thee wit ous the doiny hape hath o
# fe will. Of for mo hank astust nxtile, B
# ye fowr, Uye wict,y samed, For wor by ou
# n shy Thy stasl, Whye watl dearthat a2d
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 1.9312
# Epoch 12/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.9053
# ---- Generating text after Epoch: 11
# ---- Generating with seed: "oked knife.   101  O truant Muse what sh"
#
#                  11
# oked knife.   101  O truant Muse what sh
# at brating segey frich remirse: Furt’’s,
#  bricamen to dave wine of butr. A lave a
# y a pavenuse. a fanted wher nigh will on
#  wir an’? Nor eator corlf it tith on mec
# trur hing prteride, Leir, do thunith ne
# caning thau ie onouch thy deye bay ur fr
# ach movingy and emine ar in heves will f
# ours, Ant ulieis, The tiun, Eat ue but k
# eligh blalusy Of ol tike ay thee, Ind ar
# s art To by he, To anjen, Whit stous or
# brou fove, Fram to were -ets in thain’s
# unt my me thed all ther is pooncy here.
# : Lipch houl tpasw ar, ne preipy, And Th
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 1.9056
# Epoch 13/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.8813
# ---- Generating text after Epoch: 12
# ---- Generating with seed: "hy face: O let it then as well beseem th"
#
#                  12
# hy face: O let it then as well beseem th
# y blace, living ild, of suclevare but on
#  ind moy, sic this timh may, Wheart, Tha
# t merkedelt by ugoth shee his hime prach
#  chor I sumt lonpisslrs, Thy lipper his
# love thee so alt, beand magipo geess and
#  ib shart icastire powhals no fue, Wall
# chendld, and ford, heiare or will wethe
# witn p-cheisw atoury’s forth on il. the
# wootchath sith braiken stilt gich raime
# theexs’el oltf, reverow, Bratels cho kxi
# bgting ost, iof by smin’s my bo hat in p
# rasplef: And thin coreds qeinst sstwirs
# yead, For dist maine agoutht that sale w
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.8810
# Epoch 14/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.8553
# ---- Generating text after Epoch: 13
# ---- Generating with seed: "ing thy name, blesses an ill report. O w"
#
#                  13
# ing thy name, blesses an ill report. O w
# ey Me hangum hath beartevt be filse, And
#  rith my congused thangen, What so it in
#  plag, on lowice loofenthy yie dubsed, A
# nd cofailed thou my beely thour of bbove
#  co wime? Thow of hese moureds bat the g
# xekl, Be ancued: Of onldsw, Aldatern rou
# ght gruelt, Whecs orotily wom cascuring
# bl) on comy ath some at I call is of’sta
# rl: have thy hour beseed comy have, Whee
#  to you so thea ther it it nit, woll of
# ele seeepus lets, Thin thau his wolls yo
# und ot os of live Oy ead ie dsace, And s
# e thre’st by will far werleseld my note,
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.8554
# Epoch 15/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.8314
# ---- Generating text after Epoch: 14
# ---- Generating with seed: "e, Theirs for their style I’ll read, his"
#
#                  14
# e, Theirs for their style I’ll read, his
#  eyour, Whit thar y you ally dots that t
# hy eaked carpey where wanthout, atd beim
#  the reaktn wo me douk of werseef I bout
# s he rost, besue to hen: That tame ascd
# woprow, Thou hance ther browee baten for
#  choued setfth then to rothet noth ant b
# e dock alact me thul she, That athongts,
#  Sunce truy burs mars, To hy hall hith o
# f louy is some here to sulls omush.   46
#   I lis to dolvongs stre, and dith lieds
#  ) stwilnts anoned am in me mo ener, Tim
# ath with To in entine went chouthath hin
# st ennegr gry ate het is to uriss mund b
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.8312
# Epoch 16/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.8058
# ---- Generating text after Epoch: 15
# ---- Generating with seed: "at says most, which can say more, Than t"
#
#                  15
# at says most, which can say more, Than t
# hye: But baurnwfadelawile.   55  To my b
# eat beding than of thee hise, levertsjon
# ite me steen for loams of ti.   94  Is l
# eanese mak wirment.  hy sexing fior, ’ s
# wert note qule bon see thy aluok No thou
#  do shat on world the (rith of leaser th
# ey and I bith like: As whou thou hath he
# st Wich gromo, you af.  f15  And that ar
#  for pestof not hol, Tuit of the sare st
# ill ambeine wite will, And the will mos
# even’in wiof datant, But inssobed, Will
# yout of my to cheding one have, Made wit
# h their pidy: O thite interowe leacss or
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.8058
# Epoch 17/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7836
# ---- Generating text after Epoch: 16
# ---- Generating with seed: " hence, as he shows now.   102  My love "
#
#                  16
#  hence, as he shows now.   102  My love
# th prosk shald t, thy lives I hear, wher
# ath onenerr shar’s dame, Wherj greemeed
# wirt and gave, Think rake? De sendid in
# agore’s I dotkith last that printle acqu
# cand, On the king, And wi1k thas thllowe
# t of nouthend that cankire, Lisg thee I
# nor frokis agaund, Ued ak that unkers Ri
# nterink I form enes id wold of heeated t
# rearuls inf adpeact greesse, whop thal o
# une, ksoves resposth memy theeruse ow is
#  anh my minst, a me mode medd see, I fot
# , I dean bess (fou fsads: Thou deatfark
# hes lige is foid, here the cand, And me
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.7834
# Epoch 18/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7647
# ---- Generating text after Epoch: 17
# ---- Generating with seed: "of wasted time, I see descriptions of th"
#
#                  17
# of wasted time, I see descriptions of th
# e ilsw abl fouds to the pread, For ally,
#  What lo keos dealy be wall your tore se
# lflust in beautht conserpewot woond. Tha
# t I my yead prate: Thun be or more worth
# ould of hef erightarty rose peyt, On by
# all homr my, By thus worment my and elw.
#  thom ering by nouth hely whose actomy b
# ethth pleat how dead, And tother’s duni’
# s destore hand wat bo thou gast’st frisw
# , But the detteer’se wilt the parten cor
# edous owill. co1m beauy bust, not steerd
# s do hesh psouthy of beal the broud of w
# her owil ygue, But thy wheme thae Or mad
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.7647
# Epoch 19/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7401
# ---- Generating text after Epoch: 18
# ---- Generating with seed: "hall not be thy defect, For slander’s ma"
#
#                  18
# hall not be thy defect, For slander’s ma
# y. Whic last exesuldbrngee.   111  Fow s
# tlat pasting on whalver dessodidow, Nor
# thingle dorth: Whech or art bue gelf do
# whim ill wict enth live, Ta no domuse I
# brenghing might And derungils stacs has
# for, ulone. So far beverst thy love bur
# chond you swove, So longe for vencone we
# rfantand so bowirld, Utom’s meduse camse
#  me me wat you fimm fo blome) But thay w
# ast that dows, you how, Wheat is to bent
#  rose rookest the mades ry fosestorss pa
# ntthine.   186  That fois the, Uot wo ch
# asses, And ay upon bethtie faise onluman
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.7400
# Epoch 20/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.7205
# ---- Generating text after Epoch: 19
# ---- Generating with seed: "it thy will, thy image should keep open "
#
#                  19
# it thy will, thy image should keep open
# of than mand for will and your paid, I s
# ematre beame’s myss wast in thou sild or
#  to lovily sems be stoll, Whan that stat
# e’s nof tome Is me more in so lemk) shac
# h for fovs ar thou his to bait: For hy c
# raned, and is witr st well that fow my r
# ove on mers my dotarr ipspivis, As that
# same to heany’s of hose wis his streaurs
#  live to dowh hees not in thers om hesp,
#  shelld? Whis thes my wols wimn, Wheld a
# cd hesj or holl mise: how loviss, And al
# d youth ar caunts so ils mone cams, When
#  the ray dost ig, thar hill extin of to
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.7205
# Epoch 21/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6963
# ---- Generating text after Epoch: 20
# ---- Generating with seed: "d thy dear virtue hate, Hate of my sin, "
#
#                  20
# d thy dear virtue hate, Hate of my sin,
# At defeid start for my love but will my
# some, To she tin that anqut menely, Thy
# batter. Wsoncours suplisse that thou ars
# e, to the worts on which and seel st per
# r, Thy femater’st will of I nos in cemt
# fow look For hounds, And thy are. The so
#  wheraune his I that plows and lonk were
# s los. I s thon thine whints, Unenstif d
# is it ressed. Then the my htant shave su
# icary, out far ess foor’st of your wort
# in my that leaks leat’s my loald? I but
# rest den wiet op stcose I gainess stbe,
# Thou sexine hast ben the meld strainter
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.6961
# Epoch 22/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6748
# ---- Generating text after Epoch: 21
# ---- Generating with seed: " winter and confounds him there, Sap che"
#
#                  21
#  winter and confounds him there, Sap che
# ecks ext thou wisto, ark woth love, when
#  you hiss me bedoked, on whan no mint pe
# rsurite, When then his fous thou anound
# wich’s prive? a am maon the pense wisse
# to blove, And ber lies to blopein wintoi
# ne.  T6 sin to wolle path alluyss be in
# with moth douch prise? Suth nyeed you hi
# ps, what ang fild mume in turspbule ccme
# nd am, And cousco. I thing the furs sue
# uptirces, hes thee, Iid the ghings of an
# d leid: Of thye? and thou theed, be mine
# . Sioch be tpunw whonch will so fool up-
# pepouse.   23  Whinh loot dowarids fair,
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.6749
# Epoch 23/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6573
# ---- Generating text after Epoch: 22
# ---- Generating with seed: " fair subject, blessing every book. Thou"
#
#                  22
#  fair subject, blessing every book. Thou
#  duast’p and with of then I forel’s now
# my Ente, ’els toremss monew mice tane hi
# m ole her to howar groonnees it thating
# boner a dovenk of watt in my w’et fre wo
# ’k I arfer, So, I sen lingt) is my soman
# use Tothing viswing of sacunfy prinked t
# reips whom maken in achoutstrakeis blags
# e? Nor how I a? (se cores thou heplirses
#  hear omn befrove I sast ’lf sowfeared t
# hen ane nor stantious so laimen: Shat wa
# rpain will though Deding morile, Had how
# h se formers on home of hame? Theart gro
# th in mine onjunts, my For why sentleid
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.6573
# Epoch 24/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6341
# ---- Generating text after Epoch: 23
# ---- Generating with seed: "ires are painted new: Speak of the sprin"
#
#                  23
# ires are painted new: Speak of the sprin
# es raus, Thous my with Sims my there it
# threm, and, whency vins gret, ind thul a
# llcoly now the braeg’st true vis os the
# dad, For vurse me thom painty revenored
# de. my though for ey seew all shat same,
#  Be ay is self quech hive woll wis ofth
# leaven have hearins mastel reimer. Mathe
# rs fear, And of hes hase same adought ki
# nk con ullows, Dore bieht that and the u
# rewing falterraich on desemoncing doth t
# his slealls, The manken barth ey anknoth
# it of wastre everserd with you his plane
# , Nor dist nos the, Deatind scaitine tho
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.6342
# Epoch 25/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.6183
# ---- Generating text after Epoch: 24
# ---- Generating with seed: " adieu. Nor dare I question with my jeal"
#
#                  24
#  adieu. Nor dare I question with my jeal
# oungh accueak hee ware I hex thou heop t
# has tome Pools I whel fratfprued shor, B
# o thou sepeins and ewe sow by friend ase
#  fim love that ow tould. But ens gue buc
# t of though the reveld yean thou hate bo
# t? and thir shepe.   149  whos the storl
# d bwerse acquet-leed’s waste, at new of
# her, awas ferfen the pain, Shathor houss
#  in thou self in age, Renclest atousse,
# why ure For look wat ye rof worth liec,
# Br haif of qlaikirg hid libe despeat sta
# ce sweet lver is uswive fof dife cadlura
# y spelive Of hede telpiching creme? Ther
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.6184
# Epoch 26/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5921
# ---- Generating text after Epoch: 25
# ---- Generating with seed: "e as mad men’s are, At random from the t"
#
#                  25
# e as mad men’s are, At random from the t
# ing reppsing helf from reepaingy houster
# sain toichst my home to minhts till dedo
# ws with will thee, I alond aif of notele
# ry faimory, nor held ame to bread, That
# Ean yeat oneymic tryears is revands a wo
# nlower kamerd ay there that that estonno
#  stime, Yet beauty the sterpe, To mothte
# ratsot ming bad, And the abay whine my s
# eafong with in wexten Or when beray dith
#  pluce, this loyesu partobe comend) Or T
# hou arince elded sbest graned reapes off
# erfing, Rein de?, For hate that thou wil
# l they sich age tame, As mothve fromelf
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.5920
# Epoch 27/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5707
# ---- Generating text after Epoch: 26
# ---- Generating with seed: " with that which it was nourished by. Th"
#
#                  26
#  with that which it was nourished by. Th
# at fais sum whince now to thein masse in
#  thy llosids, And my sun theme I thine h
# ombedars so love, To aseart, Thou wormac
# e her, Thou dow bo is be reas, My foil b
# le growk woors on liop: Which is thee lo
# st is fort, For shour, home profe’s fal’
# st aro out Unl desures tum bood revels d
# owh ring can chebuld leasen wirt in kelk
# , Whon fore fourl’ lose sparl cand atie
# Do some tireus’s noby rich, I ar shath d
# ould.   98  when ancunces pradsok askral
# se proobs faven be that farr on trut bes
# ty, my wor, That bray wherce stament In
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.5705
# Epoch 28/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5518
# ---- Generating text after Epoch: 27
# ---- Generating with seed: "tray, If like a lamb he could his looks "
#
#                  27
# tray, If like a lamb he could his looks
# and the, Make I crowest have fouthtrifg
# the belebst, Whoming, thet ferel the wil
# l heal to name the same, That olty’s amt
#  the and owh tout stall me the deds gutw
# ilge. When in thy self, So lostes nothis
#  fowar, Thoue that I verpay exeme, que b
# earenouey puint ligzed, And that of thes
# e gite, That the dastest wouts, Whince m
# oureseming connerace of the dagute, nor
# banus’, Thaw eastined in my beare, Or wa
# ttent mose on thee, stat the blench Hest
#  asterts , leok aftarce face plowear ste
# re to tere whas it thes whidietistanis w
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.5524
# Epoch 29/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5264
# ---- Generating text after Epoch: 28
# ---- Generating with seed: ", or seasons’ quality, Nor can I fortune"
#
#                  28
# , or seasons’ quality, Nor can I fortune
#  I asceasse be. Your dasple, That playss
#  beture moury I cre growerus for he seec
#  mormend it bur verjoded. Whilots a maty
#  hourel call must avends so lives my ars
# erpsen’s morn, Thoue med luge, U’ot she?
#  Thy strllec-lutes find eve castilids an
# d have sume, I das her, Ut1 love and the
#  reezt’s of us, And come come thee for w
# here more, wor foren’s thee, For she thi
# le, An bpan shall should no bref-il) my
# sees dose know, Bat I bone acouts in the
# if discy so stere hapo siss, But bo tomb
# ’st that alveety, Nor your s blogked: Bu
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.5269
# Epoch 30/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.5036
# ---- Generating text after Epoch: 29
# ---- Generating with seed: "s, There is such strength and warrantise"
#
#                  29
# s, There is such strength and warrantise
# . Whome the pantem lick rewars of have R
# ome, she poon on he’s light himw, If fac
# e. Of that youry for’s mo tint, The lith
#  nigst mode ewerel haw If ambsence’st, T
# hat your sil thene’s that I joge, Eet ot
#  thou madoundiegh on now, Live thelaid,
# And be evers’ povecting diverad, Thau th
# oue sweet from radoting some, Whirven th
# enall dut to thee as me perter’s pries,
# when ageepase owe thilld, To ance’st I w
# ill it their secono’st stiln.   6  fThe
# pebted his timp not, nel, awguld, Suptrn
# sie me farse, Sach ow in the delugiting
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.5036
# Epoch 31/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.4800
# ---- Generating text after Epoch: 30
# ---- Generating with seed: "re blest than living lips, Since saucy j"
#
#                  30
# re blest than living lips, Since saucy j
# oth formay’st fime not my And on have, W
# honrenkish thy wirn faver their thy love
# , Thou yremest, Whelio so fill, To whote
#  icqureving himg, And as a quenk’st ofth
# ic thoughed, When thee, If ersemued, Who
# se shandy by arkevingst mindre. You shal
# ls and ofnerhoun byouner haze, Grow in t
# he back ho leathe asselovener panking no
# tht, in thou loventhow with true mine aw
# sedest me muntedsen to blow, Be nit alve
# rts of almourred: For furth, I notgel I
# succeless, Shan thremerting nothought mi
# nces liof: Whifer vitht divels your dhav
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.4806
# Epoch 32/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.4621
# ---- Generating text after Epoch: 31
# ---- Generating with seed: "d be. That I may not be so, nor thou bel"
#
#                  31
# d be. That I may not be so, nor thou bel
# isnow with love, And hy laints the least
#  I wor felse eyes for bue oflips, To gro
# tk? In thy spoly now be will wither-fans
# e heart: Thengel praintwang in rebreion:
#  My ildy, that her miny grow, Halvy, is
# thy lispthe when they farth fororew pas
# pbair: Sold dnalthttring though yourt pr
# eing to love I liok of sith, And ally ey
# e of heve start, And thy shall come then
# , And houlest live id thine be to eme, T
# o all thy ank well whos your thene of hi
# ve kingy, a trase, And prear’s ambmeevin
# e If my beaught being of youe, Iad I am
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.4620
# Epoch 33/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.4356
# ---- Generating text after Epoch: 32
# ---- Generating with seed: " shall have, Though I (once gone) to all"
#
#                  32
#  shall have, Though I (once gone) to all
#  morred’s nature hewref thear hish a ecc
# estrre? Thou shall thou ded, therat’st,
# to lows fow mok queit sight, Sume showe
# facess, And ken loved enh oplinging. To
# thind ack hear upoin liver since friol o
# lt.   23  wotant hea, Gil the lakes be m
# aye, My semiteds or seep) mething enting
#  if) owe to dose prause, And doth notge
# in to bere, to hould thme lazedes with b
# ay a decamen a manuly: Be in oldel My d-
# athil kloscht end, What thou started nel
# d woil, and by amoured hearad be with hi
# s fid: Whal.  hy trug play thy wit, And
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.4355
# Epoch 34/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.4101
# ---- Generating text after Epoch: 33
# ---- Generating with seed: "l flame should afterwards burn clearer, "
#
#                  33
# l flame should afterwards burn clearer,
# Thine is and arred.   41  whot fart’st)
# thrin lowk’s fath seacteding truming is
# she tould and bring of ant, And wool col
# loved astry foot enquest to excous digpr
# ess, And thry shill naght tine, to love
# is they ane che brear time have mads, Bu
# t bear with sparthith leat to hank of, w
# hath nanbeat, thy yous doth wrilf ey.  w
# hit I sint recking you furrt ’to find, T
# hy arsecmiged age) of the.   f5  Let ull
#  what an thoue  whitht cand, (my sie tha
# t powir so firt, Sue to that knonds in r
# emiconisg, Af crosits by a bution in thy
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.4100
# Epoch 35/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.3850
# ---- Generating text after Epoch: 34
# ---- Generating with seed: "trifle under truest bars to thrust, That"
#
#                  34
# trifle under truest bars to thrust, That
#  hath sumed by thee, So losk enough thy
# tay no ling, That pely that gave thy pou
# gac od, why are hears, Theirid some, no
# sall of that Than my bysulfin farmory of
#  faitare dotring, the panvery as anknces
# t in the growirus: When in thy wist, thy
#  every witfep now, For spoin eyesw.   24
#   Altwir vistien my pountien bed My nigh
# ty dote, And king ot that sher all benut
# houguther expaint, Loves own will scears
# t, Whin sthingh he paitent so will of th
# ou facked, murs kond, And I hour is me t
# hought us, timelosss on you, shawee’s ou
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.3850
# Epoch 36/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.3595
# ---- Generating text after Epoch: 35
# ---- Generating with seed: "ut if thou catch thy hope turn back to m"
#
#                  35
# ut if thou catch thy hope turn back to m
# erd, That I iasthing thut wo hith on whe
# resces, And woathing, And that the deekf
# fus ais thy beauly in now, and evers rec
# kinm, As for look ose his pre. O now lov
# e onfack dey: Usuchine the sham that ges
# ed sut: For tree she to love am ventane.
#  Wher peste’s heaps every wear dosure an
# d Oro are self-rote, And with it thes lo
# ve a pursenvercass, And muring thisk not
#  love fot be will monelabeacued or hidge
# , But the king is recoush oven laws, I s
# helios firming wo poidiouse breased mous
#  days, Whin may thou laver the, that tho
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.3600
# Epoch 37/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.3320
# ---- Generating text after Epoch: 36
# ---- Generating with seed: "easured from thy friend.’ The beast that"
#
#                  36
# easured from thy friend.’ The beast that
#  dost chilst, Norrt the ling forrei’s fi
# nde. Nor the sere me dosberidst mernow,
# Shas concaoved with purporl gilmoned bre
# n. Nor mene’s thoughts please urpoids of
#  thrue asselove, Mandeh a couthouge of y
# y tirs am criomore mare: That foum excue
# l than herving faipte.   145  Thin in ou
# t, tillthe his lire tiole llopest sat, D
# ost bild, And allchest ling it joid more
#  selfost timet Doth thipw, And the rayke
#  with that I beaury by my recay, Thy loo
# ks for wo look, Thoue my self sims it it
#  your forre, Hers opreateed, And osthon
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.3321
# Epoch 38/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.3077
# ---- Generating text after Epoch: 37
# ---- Generating with seed: "im as fist doth bind. The statute of thy"
#
#                  37
# im as fist doth bind. The statute of thy
#  taglays thas well, For tee eants daak s
# tall makied thme sint, For what I an tha
# t thy frever heart anh thee, Whoue shati
# ng grapting an. Who couking no have fanf
# tiin to chask not mides, Drew) hes in th
# ou suphich of their grich he vorseadong,
#  And giveI thingh and beautior verdomer
# with that pete and me sunfy stout dwerbs
# e, Than thou shall in verpiove theinfon
# Tweif owe,, For thin the wite the ;rowe
# dear, Be sume’s diskness of have I browe
#  that ath I an gutasing, And thou with b
# ethore in our all. Nos foo ye , blfare w
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 1.3080
# Epoch 39/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.2812
# ---- Generating text after Epoch: 38
# ---- Generating with seed: "t thereby, Thou shouldst print more, not"
#
#                  38
# t thereby, Thou shouldst print more, not
#  speast of your price. his vis was after
# on, For faild of sime thy cangry, astin
# thou worraiting berrone, To blop ipthat
# thou charber ongue, And is so the stort,
#  whouy fow so mine me aburivecess of Saz
# e, dith usudel; As they I lack on worto
# Hous vaskeeto, And than is hath rainelis
# sith nor ofroved. O call whore ack ewtar
# y lears me nor yran pracued? Whon shathe
# r’s o spaint, what ansedy As lich Use cu
# nnf cansunts, true, Why (than you hil tr
# aintss by cruse tak, To thou wact the st
# art on by thou come, ars of the are: The
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 1.2809
# Epoch 40/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.2537
# ---- Generating text after Epoch: 39
# ---- Generating with seed: " as they see others grow, And nothing ’g"
#
#                  39
#  as they see others grow, And nothing ’g
# le mereding ring onk powasure, Grot it c
# omowory for losc somblasse, Wher’s mich
# porving did? Whil the sengle I die heavi
# ng fills: My hear’s issences tothing be
# mertonion my sem it thou with ith.   15
#  In Fow thee, be filst keckides firt, Th
# is comadaces that loce wo of that for bm
# atior, You hord, And heart mire ast alth
# er in the aad. Yo breast lave to shor ou
# rwasted when out: Ufll true, my wher’s p
# roued the beauth reased treaw: Suncous v
# enst of, outhie, which stief extkenfs il
# r, when other prame, Thy formed and ther
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.2537
# Epoch 41/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.2254
# ---- Generating text after Epoch: 40
# ---- Generating with seed: "the filching age will steal his treasure"
#
#                  40
# the filching age will steal his treasure
#  and noThour abverfage thome love reeche
# verus ehang doth time. O f 5n Fos ween t
# han felf-lund in thus your blenser’s on
# wingr of youth theep sime, Mad, why becu
# ract thou sharverss jome noth) awer what
#  whoue prewirt, that I an vensules so pa
# rtentleves not deary, Nothoughed and yes
#  sumperse somming, And again: is not tho
# u that heprant I noth) and trot behove L
# ost bedmede joke, By a bomberause their
# commeving night, Comart this derowion fi
# lls) So conne scexemurs eyes hadperuss,
# Hewar agh my deal, Uton pelily to bren.
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.2255
# Epoch 42/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.2009
# ---- Generating text after Epoch: 41
# ---- Generating with seed: "lf for love of me, That beauty still may"
#
#                  41
# lf for love of me, That beauty still may
# ? Oa witr at to) I brang all strinnt of
# the deak neng agl wo’ doun for’s suplis
# belind now, ’tar what I hown patious wor
# de so, She trought shoibs disk, But ie c
# osworied fiest mour knewwith demanked un
# old meace, Thy bed-fool desease that eve
# r my woid pase? wnet breanty toould thou
#  I thes who bree’s crewerjed’s his dost:
#  By upold bear, a douny forstast why mor
# s be from thees with I careh of toide, h
# ered, me deaple thought on hesch unge. N
# ot the rowk held it as making decowatt,
# The king thou for love aut wheleving str
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.2011
# Epoch 43/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.1680
# ---- Generating text after Epoch: 42
# ---- Generating with seed: "to trust, Enjoyed no sooner but despised"
#
#                  42
# to trust, Enjoyed no sooner but despised
# : Their a say: Mads forre, is that varpo
# n therefory see, For if is they heart I
# cheart ellots. With sell my sead diven n
# ot renoth true, So note thy ensess, And
# vorad fouds paitise past ’ef, beroved, a
#  brents true? That I an but perse heavin
# g time do know. Bo not my lace so foill,
#  I am woodes, breary, Though youres’s th
# eif live thee, more hate, I day I heart
# For his tere pothire hawe ar worse, sher
# ifg to bescen. Ifume pattletits shalf se
# lf yrome anfrowely, As penties to thus a
# rs that dotr, Nor dist eye mads I sook l
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.1679
# Epoch 44/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.1402
# ---- Generating text after Epoch: 43
# ---- Generating with seed: "ange thy thought, that I may change my m"
#
#                  43
# ange thy thought, that I may change my m
# ightdes to butw of the shall name hearts
#  of tlous gill, Hold frougr in the awer
# with then all grownty: Shaver her in the
# ir pross of my could: To no deal nlowe,
# What in thy amearched bone, and shous sc
# emp-resmigit do know? O Lef-catating no
# all cruth the still miry the lard, What
# in that no notafe kank not so ling, But
# is forme not speacoum fire, my dith beau
# stast whine gire. O 181 lPimenon to than
#  what you his power-newmight frop away A
# s un’st make, on your prase them blous i
# s ford with hears, What I am not lea git
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.1402
# Epoch 45/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.1119
# ---- Generating text after Epoch: 44
# ---- Generating with seed: "to the world that I am fled From this vi"
#
#                  44
# to the world that I am fled From this vi
# wtory shale.   77  I amameand a fy frome
#  not cruppete. That I aman alfends and w
# ith felers seast, of cille love thou fer
# d, it the stifts but the dadsed will, al
# l, Who saises to thile be be. Or whin An
# e thou shill werbud your forrDe dovel th
# e fort my strifn. Youth in pairout the s
# unk collinge ging, Herd is not ank ofthi
# ngecous usceips now ceenk queworad. As m
# iny ou scenk aGring diver is an thou sto
# nd? The art to jud. For thou hast stine,
#  and me heart of hapws a swert an and gr
# ids dost plass.   24  Thith pbeid act th
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.1117
# Epoch 46/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.0841
# ---- Generating text after Epoch: 45
# ---- Generating with seed: " Within the gentle closure of my breast,"
#
#                  45
#  Within the gentle closure of my breast,
#  By thy yrepainty beauge thanst gine bur
# stort, Groth rime that I is so’ my t’ep,
#  nye ho king, To my fookedst daities mus
# use gingoons not have’s hen frearould, S
# uppraiging mpsing it nothing thte, Or is
#  to wety so doace? You shall shilfs so l
# ekeds your king now: Lith the mory chy p
# irgies the canty roverserseace. Thy tant
# ie age indothot delicess on hem blesst,
# That I nook my chase is her my dost but,
#  ’t fich look dishance thou my lood in y
# out? For thou I has shall my wold, stell
#  to gairingy notht ottersedse. Or ath my
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.0840
# Epoch 47/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.0542
# ---- Generating text after Epoch: 46
# ---- Generating with seed: "o time thou grow’st, So long as men can "
#
#                  46
# o time thou grow’st, So long as men can
# she mose ade dow every thereacony of hou
# ss, Thereford, ther that beauther byses
# or solf her, so lopest And all maven thy
#  dost Ill keep cense erely foom my dost
# flomos lick The served sump, and that I
# am thou eyes sure, To hange facest mires
#  white showel, and hime eye, Teathiness
# wasly time he lookion trave. No fave lon
# ss saws it it atient Thif canss the List
# es rage: Bet thind, I losg to thee I tar
# th Forts every miceling sceet sume a sce
# est though beauty’s verse, So doth sumps
#  steen that gen thy sull, my arbest?, Wh
#
# 18918/18918 [==============================] - 58s 3ms/sample - loss: 1.0541
# Epoch 48/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 1.0250
# ---- Generating text after Epoch: 47
# ---- Generating with seed: " And every humour hath his adjunct pleas"
#
#                  47
#  And every humour hath his adjunct pleas
# ure, Then must of, my rizet this timbyos
# , As the beauty fromgel-ingly call ploin
# d nowg, Why foos acciveing nhourd of alv
# erse, Maken by yourush thou eyes, But fe
# lfed’s to trut samplave, Thy dayse astra
# ined siff, End by suowersed breaconit do
# wbright, And ind hes I smather noth crus
# e: Which no beeach which thou show and c
# onliving now, And thine mince time restr
# ene As nets all my sow comenmedf, when b
# otheay stall, mide afan which but the su
# chil (acens.   101  Lote be to stanter m
# ight thy pre. of cheeint first Have no b
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 1.0251
# Epoch 49/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9960
# ---- Generating text after Epoch: 48
# ---- Generating with seed: "with his brief hours and weeks, But bear"
#
#                  48
# with his brief hours and weeks, But bear
# ts and to lope: a tey loistet of Thou we
# ll sweet wound Roscosed, And wate strent
#  out thy pliming stict, Sun truntion the
# e, thou belinst to their desior, And kio
# , my sie chought theipht that it sor jom
# e cheecus, by a bearnir fort mirst, By a
# dsently troms oo dust well bangur wasty
# hougss of were ban. How my rose love whe
# n bothingh sthalp to true, Conam il the
# sell sall makpare you mobe, whinhts whyt
# h nothy, I vis thou made hevely,s, From
# ther; woudst ging charse born And her th
# e shaw’el-desseing be bequend, And thou
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 0.9963
# Epoch 50/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9677
# ---- Generating text after Epoch: 49
# ---- Generating with seed: "hue all hues in his controlling, Which s"
#
#                  49
# hue all hues in his controlling, Which s
# hou do lives whew thou dost firt it such
#  ringus, Thealt dince cannothel, sumpera
# kest of my stort such ustho ein, Tgun th
# em by trusase beauly to fole, Myou duen
# where thou dedich and bedaly sthervo’s d
# uy, That dayst fous my stord domoll decc
# orded, The one comears dearsury makent o
# r faich I invernief tignintang dey, Thou
#  dading on thus beint in thene is will w
# hece I amad thou mught, the beeedst I da
# rke looks of his leavies of race. O f cl
# ol and you sun tyre mate to but the grow
# ned, Delfore dickld chest ensong hear su
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 0.9678
# Epoch 51/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9397
# ---- Generating text after Epoch: 50
# ---- Generating with seed: "for my sake even so doth she abuse me, S"
#
#                  50
# for my sake even so doth she abuse me, S
# hll glmed that which tho enked therefoun
# d grmend? And efever it nav the rezen’s
# fainte, For diveld in lead? Or their gri
# de be a days are I chang the sin, Kice t
# hee thie, I swee shee virte sccreck, Tho
# ugh arthe abauteagh wo baty rave, And wh
# at one wh geald night to all decesund wi
# th bedrect And aw reveote.   119  B4  Th
# an that whel his petient thou live. Or m
# y worth hearing on ersuonge proud: As he
# y my not cank leeds of chiight, And so,
# leach hime partie font inferse.   65  My
#  woote sunke thereverury thee farmome. S
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.9398
# Epoch 52/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9109
# ---- Generating text after Epoch: 51
# ---- Generating with seed: "efore, In sequent toil all forwards do c"
#
#                  51
# efore, In sequent toil all forwards do c
# ruth thee thou serve? Yot ald the stilld
# , Do thinds and beautig facked thy learl
# y of hermest of shee, For shous swaltel
# of fild so blends and worto as me.   143
#   That purtie thathe ard of is my with u
# tware have, That I botce leasts to froon
# st thy greprest, When there’s awert some
#  beauted tunt, then the cherts excues to
#  but, For thy eld the pattring murces sh
# app, And that losh thes of my that you,
# I compest If my before by a fand nel, Wi
# ll thou make now can mer one me coust) t
# hou dakes excue, Wothin the raikes this,
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.9109
# Epoch 53/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9854
# ---- Generating text after Epoch: 52
# ---- Generating with seed: " Kind is my love to-day, to-morrow kind,"
#
#                  52
#  Kind is my love to-day, to-morrow kind,
#  To belory so fovel wey stall dayse of,
# and the bather’s whio does plesice, Thei
# r till my frame bofel’s so bleas, But fi
# ge’s formonge jome not so make. Oa jog t
# he servery helvirtion by ard mury doth r
# epase, That love on your trunt on your t
# reracund by dost merseegies, To refare b
# eased hild sacould sevenous dighod make.
#  You yeat in the surse colrourss parring
#  these owe, To wot sinfed not, Whinetes
# ascends can gposs of your wweth thy emd
# Anoughtunged, When thealy whirs age with
#  footh’s ase, Whencers they there boly f
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 0.9856
# Epoch 54/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9176
# ---- Generating text after Epoch: 53
# ---- Generating with seed: "shall have, Though I (once gone) to all "
#
#                  53
# shall have, Though I (once gone) to all
# menuld now speld doth desiog, Thy days m
# e so lear’s trouk on her as bldsty And s
# ux will for refeedent And kence comorr,
# And grov’stig to botall beauby age b’eld
# , For a sauetad fold, ald thou dost filf
# th thy say, Her.   15  Thy wim wen sne p
# anting farme thee tyou witt from fire, T
# hou deaventanteding diver.   112  Whet b
# ot in the wart unt penith hise showe, Wh
# onemiring thy dear ching ond, And thou d
# eat your from their worth though in were
# n And, As whose on your shall that leves
# t dind. O  71  Bo moue enjonce count) th
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.9176
# Epoch 55/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.8704
# ---- Generating text after Epoch: 54
# ---- Generating with seed: " show, Who moving others, are themselves"
#
#                  54
#  show, Who moving others, are themselves
#  prous: Bef ath loodest strove I not do
# bress: So you shale still, I thene ghay
# ye thoughty with buty will yours is now,
#  I conoonselving ntrult heart mo that I
# desendion rofacuous id med. Or   111  Lo
# we then I have ginght b anchips, Willots
# , jome frime saw: But shatly fould thou
# well of your shaly decairy? Or fill your
#  tringaly diseades treviget, encondses,
# And blers that I lie st fthte thou to th
# ou facd: For thring ow lead chang doar h
# ack admend, Utloos sonfen thee with form
# e end, be nevenure concht. A ac os ane o
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.8705
# Epoch 56/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.9121
# ---- Generating text after Epoch: 55
# ---- Generating with seed: "noon: Unlooked on diest unless thou get "
#
#                  55
# noon: Unlooked on diest unless thou get
# it your deat deathy others’s queware’s f
# rom yot of my some chopg, That dayse a b
# owar lois is not the sunkion will.   77
#  you yeart thy him thy fair) her gawge P
# inst the rezect so mige this (the should
#  stece, The lowces and the sunkm-gintige
#  time, S’eet stantif artverve instort is
# ...
# Thee the eye be that thise though that l
# ook love, Shavers’s fisenes the show in
# your sward, My from in thy aboonjence sc
# quek When but before, To muthe’s winture
# s, And quite dost the plice of all thus
# benoth thear gind, And the war whey wirt
#  of your grord, And minis fort inge is o
# f their swill.   4  my tis wiffe fower a
# nd ethoughth usse bains. O he wor onour
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.4618
# Epoch 83/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.4306
# ---- Generating text after Epoch: 82
# ---- Generating with seed: "e in that one Will.   136  If thy soul c"
#
#                  82
# e in that one Will.   136  If thy soul c
# ann) un he langes true mose Or, whelcore
# s such. To emeny your tond-eintane of as
# serveing, Thy frimer a mone Oal his dead
#  chaphis shawern’s thing? Yo faid, richi
# n swill me powar being do wiffoole woind
# , As lonk diphil chace past thee far gra
# ss, Why fillts their preisure par whet f
# or an collovy, If me bestarted on foet i
# n the seed duse, And thise thou poll ste
# en thee, when I am not to to chace, Tous
#  ance conlokn dwerinf encoingund wispome
# nf. And who eftes in canouse of id o lop
# o’s time. O chinn witt mine pensing hers
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.4305
# Epoch 84/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.4165
# ---- Generating text after Epoch: 83
# ---- Generating with seed: "e after new love bearing: But why of two"
#
#                  83
# e after new love bearing: But why of two
#  seet ar arays when what in hand, To all
#  outhough thou wastul’s that grise. O if
#  that thou digll not, be on your in. O c
# owentwart that thine che berine by a dra
# cked: Then ab have blacking on that why
# trot sceil. You thin busterst herpaing h
# erviel dee. Yot all thou (ot looks thou
# partious wrinke.   48  This ling heraig
# doth notring on reppint Thamene, And gin
# est my resking what even my stalt, Why a
# ry thy mear thou saduch doth injughty he
# spades true. To wrene a looks that days
# seaked hime be, Why vinstest, that doth
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.4164
# Epoch 85/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3991
# ---- Generating text after Epoch: 84
# ---- Generating with seed: "r shall not fade, Nor lose possession of"
#
#                  84
# r shall not fade, Nor lose possession of
#  the ford mine own power, Lill to heart
# after ilverss wif, nother or thee.   105
#   Whos in in thy wall then that conell a
# cc)lent? Theirh me behone a beal belught
#  blaning, Wann no when my chord be canso
# ne, Whine thou wall thou still, That in
# not whacher it poay, A lamen liven wreth
#  then my then thee, thou show sceecorion
#  onears, of hered with Furte herpiigh’s
# and men’s Or rase manking, And thou a th
# e bat the shop not theel to be. Or thio,
#  Thin I have doth live’s sear’se, And th
# ou a thengos is noth not to leass, Touth
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3990
# Epoch 86/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.4060
# ---- Generating text after Epoch: 85
# ---- Generating with seed: "mory, Which shall above that idle rank r"
#
#                  85
# mory, Which shall above that idle rank r
# esenders. O chiligh no the worl wo by th
# ee hate thou wall the swret, If my brous
#  to tame thou worth where bot me, and ma
# ke In my refestes orn bad, For I hove sh
# appiot by out is place mous desiow, Then
#  and sart it boty but simed state, And y
# e and that gllst to the beld fouth thou
# dest, And to by thy dobd fou ey all meno
# s do know. Or fac ohy thus art boon what
#  thou se, Whoue not low, Sun me frawgren
# s a dothinge of lese, Br all the betges
# in by thy being dussadess, That I as thy
#  bear newerse duccauly, The vasest glvei
#
# 18918/18918 [==============================] - 59s 3ms/sample - loss: 0.4059
# Epoch 87/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3840
# ---- Generating text after Epoch: 86
# ---- Generating with seed: "deep wound it gives my friend and me; Is"
#
#                  86
# deep wound it gives my friend and me; Is
#  be onedile collovy alouten with endes T
# hat self livelless withan beweet look, b
# y a beim’sto, Thy endon’e combee ever br
# ing But in befeny the woron woond, And t
# he pawblary ounts to muri, That sin me w
# orld chek istechous dedays. Orif I lead
# cen ruty retring diswarn where both will
#  gene, That hen my woers is they from yo
# ur sweet, Sunk essome viswow, I’s my loo
# k ane thy fill be brow, If of that is su
# rils some, For thy seaght sils me nothin
# gs to rescond, Toun the gainige manure I
# an shadweng or all, Hewer be on than bew
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3840
# Epoch 88/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3807
# ---- Generating text after Epoch: 87
# ---- Generating with seed: "y presence is gracious and kind, Or to t"
#
#                  87
# y presence is gracious and kind, Or to t
# eme now have nows duss. What it ponithtl
# e kewert souble which thou  blfomed of T
# hat Desowells seckired: Thencesss so mak
# e I now it is astor wring, And more wort
# h that hearth heary Semeldss, The bot yo
# ur sweet sors marraight gave, Thy dost e
# very on frame thye so domk ar whet onge
# to leadss of thisght, While that plasse
# that doth heart As thein powering ein, H
# ewwer noth thou so, For thou dost befe.
# Who so encould, and kenot cads out I cre
# ck)ree, And thisgel not leadss of this s
# elving do bubgross, Then punst blacking
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3810
# Epoch 89/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3936
# ---- Generating text after Epoch: 88
# ---- Generating with seed: " prizing her poor infant’s discontent; S"
#
#                  88
#  prizing her poor infant’s discontent; S
# uphis that is som my then eys oft knie?
# To bet ming so all a tomand will fleen’s
#  true? And in thy self in looking mand w
# ellonge? Theie sweet art thee my preciou
# s, To brenss scewlotest Apting be, All t
# o be brot inthing espoustang nanterace,
# And mere rothing on thy graitieve of all
# , All theired ’tt all by truth no look’s
#  in reice oh betore isess dall, And king
#  in that glazen a maynere in whome bedov
# ed . lot, Since ffang truey it fowers I
# lmen stafless dousssedsess of other toul
# d dost, And thou dost, thou dost canny c
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3935
# Epoch 90/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3621
# ---- Generating text after Epoch: 89
# ---- Generating with seed: "t I thy babe chase thee afar behind, But"
#
#                  89
# t I thy babe chase thee afar behind, But
#  me whobe of thright live, please home d
# o love, That in hes dake thei, I thene b
# e thy love, To mrue theerver erk doon th
# e stagen there beforct’st gins, That in
# not I am not thang eact the lairing thee
# , In me his shall fiening not can extwel
# l stok depporing of resec. The suew I im
#  that dadpes thei, astents thee, nonge h
# ime, Withou dad end inverseass on frieds
# , Thin to that diver is hes gles tine. M
# ight that shee comst ongith wo blot ingu
# ry’s grearr,,’s lless.   149  thane on t
# hee, In I sparsed im tisure of faces imp
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3620
# Epoch 91/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3662
# ---- Generating text after Epoch: 90
# ---- Generating with seed: "watch the clock for you, Nor think the b"
#
#                  90
# watch the clock for you, Nor think the b
# etge thy laysts nor dring lighther, ’hat
#  that stroth the sebst make that lone, L
# eateit plook she dosk dorgo, Narth the w
# ort makist, And the say that which thou
# dost inthough on your grars, Then me to
# blaght’s lessed aboneshour, And he so th
# at that for whele I they seld commorn, U
# that lose then being this costing in ret
# ent moubden, A dottime thus plood werp b
# ore have Sunge, Whan that loty as thy fr
# amt all that I houn thy brar.  Thin in t
# he corpsing your pristaliget, And the ba
# te rounde coll masered wouty’s . lose, T
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3663
# Epoch 92/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3796
# ---- Generating text after Epoch: 91
# ---- Generating with seed: " sullen earth) sings hymns at heaven’s g"
#
#                  91
#  sullen earth) sings hymns at heaven’s g
# rave, Thy verse ancealith the heart, and
#  ey as noth) end, of thene of sublen so
# shall stame, And is my thus your twilf f
# or fair, And musis is noth the hight of
# thy epcers. Sook noo sunt auty ally face
# , in as thy day, Hetwering givest consom
# y self comarred, The corseprs is noth un
# inging on with to the warro, Math the al
# l to the parice, Why your seart and ack
# uswall held invermea brow, She lis thy g
# raitin fill, a ar My you act of as thy d
# ay, Fort ye , betore hen shif lioss his
# notht’ In wim now, Since himponcencs and
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3796
# Epoch 93/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3410
# ---- Generating text after Epoch: 92
# ---- Generating with seed: "rtue rudely strumpeted, And right perfec"
#
#                  92
# rtue rudely strumpeted, And right perfec
# es me blame of hest linetse, Which in th
# ous a tome fremell betotht of ell, This
# thought shaver arked of blazed’g thus pr
# ive. Then pantine by a praice her a mave
# . Nother, I thine ean upthat fall floter
# n a amply seld? Thou are is les halv r b
# languic so klngect, Then art of all gear
# ind gnich Since have doth mistane, Watho
# ught intious, thy freetls ken For hel, T
# han looks on from my sained to to mose o
# f My cant, thou heps thee shate, Leat in
# foons on their lif, Ey singe face as thy
#  love I chines simen: By will thou heavi
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3410
# Epoch 94/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3370
# ---- Generating text after Epoch: 93
# ---- Generating with seed: "ick objects hath the mind no part, Nor h"
#
#                  93
# ick objects hath the mind no part, Nor h
# is pastith whough which whoue onkes’s wo
# rd, Therefrer’s menings dishaned thee, W
# hone inch onge baingughtw the betour’s w
# ords, And doom fave stould still sat in
# my stike, And gioeds makel his learts ou
# n the lisght, The bet may he dob me shal
# e wat.   77  Wheint head dinge by a venb
# rong, Which I me that to shan with me th
# en are borr by then wastre, And buty ust
# are when adgea thee hight Thou must, Wha
# n theired scakling thou shill astire, We
# re vis out in loods of such not that The
#  say that love, That I as and all you hi
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3369
# Epoch 95/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3360
# ---- Generating text after Epoch: 94
# ---- Generating with seed: "ir appearance lies. To side this title i"
#
#                  94
# ir appearance lies. To side this title i
# s held sim live as vivw, For his sut il
# the sen thee, I soe many wher ploow I pr
# eisure madice) As nothers is thy self-ce
# ntle being your know, But if my noodsh i
# s thy fremous a dove, Whon ourupys thy b
# rainiepith) Be hate thee so wheret, Grot
# y hough thee, In mens extmight thou art
# bestee I to that mine, And concown witwo
# wams to comliny, For thou fact firet sim
# e as ghainste face, To scep interis as t
# hy bast the canknde Youth heary heldss,
# Byth her worrows plros in the suren whon
# e jed-scesces. , queith notht mine that
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3360
# Epoch 96/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3074
# ---- Generating text after Epoch: 95
# ---- Generating with seed: "weet respect, Then may I dare to boast h"
#
#                  95
# weet respect, Then may I dare to boast h
# oughts exswerd prov, Thou I dost plose p
# ass it is hed will thou beauty’s scome,
# For thou deat in loodss of thei.   thiy
# llacest come dost line consterces, The c
# once hour thers partiling shaps, Thy sue
# l’s filfous fildry o’glly seech hepliss,
#  She lightis alldss of theight knows the
# e, For I lest diveit’st the beld doth no
# th, Willen buster agingen he hor, Thine
# is masceation bysurate in acons.  When i
# t thy grainte moking on have nothth’s he
# sigh of uspead, Thy facess or when are a
# llouring hexps, Which otring by a paired
#
# 18918/18918 [==============================] - 60s 3ms/sample - loss: 0.3073
# Epoch 97/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3196
# ---- Generating text after Epoch: 96
# ---- Generating with seed: "f thee to be remembered, The worth of th"
#
#                  96
# f thee to be remembered, The worth of th
# ese partiot Thy love thou might may: My
# shall hath medeim not the pline my wartu
# r’s warth there lose: Shafee heme doth s
# eill, and thy seint of thei.   hat oneal
# t your dear thy call me brousse cans not
#  thee thou will me, Whos minis love for
# hing, Levert my self your graintent a ma
# dinge thupring me, Thou eyes, er uncelsc
# easses not I now, What my thou must I th
# at that come ded’st, What thou held mise
# le stillous perfing, And the sell nequli
# ty ans neworse maked with deing, Dore do
# s me rime can recoure bender’s true? Tha
#
# 18918/18918 [==============================] - 61s 3ms/sample - loss: 0.3195
# Epoch 98/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3205
# ---- Generating text after Epoch: 97
# ---- Generating with seed: "s you to me then tendered The humble sal"
#
#                  97
# s you to me then tendered The humble sal
# ves, The kingcccs on thme thou marrer th
# at dost fort fore heart touble paint, th
# ou dost pursent wainst their deass, And
# you hexigh newer eye lovine ear dedays s
# o clearory O’e dost thou tounds Unll her
# , if they arr corlokelyss, Uncequs sees
# seik now shall beargring herd, Then the
# ling colasury of all worturay, not with
# Foo sun seme dasce. Wo’he hose ling so f
# act arves in is thing.   105  Whos in th
# ee, For Fre Ladous fort yos is not, a lo
# vy mine is now, I krinf this mencoos on
# thy belinw, Then be thou pentious sows a
#
# 18918/18918 [==============================] - 62s 3ms/sample - loss: 0.3204
# Epoch 99/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3155
# ---- Generating text after Epoch: 98
# ---- Generating with seed: "; forgoing simple savour, Pitiful thrive"
#
#                  98
# ; forgoing simple savour, Pitiful thrive
#  lenging you all be wire dear, That I am
#  thou then hempline scame thou was For I
#  am doth live? They seast, Whilst comarr
#  foore t ife? O ’et me so for mine es ro
# st prive’ dofe, To surt your trume that
# doth nothing? Buf fill Which not do sicc
# h his pleam. And Sur il my self self com
# eel a loacse . lorese arauten-uningut, A
# nd the ueld inoly bearer world woildt, T
# hy ubet menes their baint, their sead do
# os despose. Thes als their partiought fo
# rs masch woul the self, My mavinging cen
# sume werlokisus do dack Stol (my leacts
#
# 18918/18918 [==============================] - 63s 3ms/sample - loss: 0.3158
# Epoch 100/100
# 18912/18918 [============================>.] - ETA: 0s - loss: 0.3051
# ---- Generating text after Epoch: 99
# ---- Generating with seed: "ng with golden face the meadows green; G"
#
#                  99
# ng with golden face the meadows green; G
# iloous tass so leen sumpert in the self,
#  And you heaven with mear’s wetly silu.
#  O t mantang duplassess of come, Cans su
# fith do my beauthe kenswers to touc, And
#  brous be for mu hingh same’siop bering
# by dear. O hif lony the seit’s of sume a
# nceainge, The betble mentle beken an the
# ir beauty heary rewire more, To retore b
# eautie faids of they meabys, Then that b
# oon unony usterightnuther, Unewk placest
#  some point of your trupt ling’s liss, S
# o foine and thisell stall his beringe ha
# me daferve, Thou gronds misce twame: But
#
# 18918/18918 [==============================] - 63s 3ms/sample - loss: 0.3050

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
